# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame
import re
import datetime

# %%
# seaborn 의 set 기능을 통해 폰트, 마이너스 폰트 설정, 스타일 설정을 합니다.
# "Malgun Gothic"
sns.set(font="NanumBarunGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# 한글폰트 설정 확인을 합니다.

pd.Series([1, -1, 0, 5, -5]).plot(title="한글폰트")

# %%
#전체 승객
data_file = '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스/bus_all_all.csv'
df = pd.read_csv(data_file)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      사용년월 노선번호                    노선명  ... 23시하차총승객수      등록일자 노선ID
# 0  202104  N37  N37번(송파공영차고지~진관공영차고지)  ...         0  20210503  NaN
# 1  202104  470       470번(상암차고지~안골마을)  ...        69  20210503  NaN
# 2  202104  N37  N37번(진관공영차고지~송파공영차고지)  ...         0  20210503  NaN
# 3  202104  741      741번(진관차고지~헌인릉입구)  ...        60  20210503  NaN
# 4  202104  100         100번(하계동~용산구청)  ...         9  20210503  NaN
#
# [5 rows x 56 columns]

# %%
# 역별 구 구분 자료, 표준버스정류장ID컬럼으로 변경
data_file = '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스/bus stops address and gu_3.csv'
df2 = pd.read_csv(data_file, encoding='cp949')
df2.rename(columns={'StandardID':'표준버스정류장ID'}, inplace=True)
df2.head()
# Out:
#    Unnamed: 0  표준버스정류장ID  ...                              주소  소속구
# 0           0  100000001  ...  대한민국 서울특별시 종로1.2.3.4가동 종로2가사거리  종로구
# 1           1  100000002  ...              대한민국 서울특별시 와룡동 창경궁  종로구
# 2           2  100000003  ...      대한민국 서울특별시 종로구 명륜4가 195-17  종로구
# 3           3  100000004  ...          대한민국 서울특별시 종로구 관철동 238  종로구
# 4           4  100000005  ...        대한민국 서울특별시 종로구 혜화동 85-10  종로구
#
# [5 rows x 10 columns]

# %%
# 표준버스정류장ID 기준으로 merge
big_df = pd.merge(df, df2, how="left", on="표준버스정류장ID")
big_df
# Out:
#            사용년월  노선번호  ...                              주소  소속구
# 0        202104   N37  ...  대한민국 서울특별시 종로1.2.3.4가동 종로2가사거리  종로구
# 1        202104   470  ...  대한민국 서울특별시 종로1.2.3.4가동 종로2가사거리  종로구
# 2        202104   N37  ...  대한민국 서울특별시 종로1.2.3.4가동 종로2가사거리  종로구
# 3        202104   741  ...  대한민국 서울특별시 종로1.2.3.4가동 종로2가사거리  종로구
# 4        202104   100  ...              대한민국 서울특별시 와룡동 창경궁  종로구
# ...         ...   ...  ...                             ...  ...
# 1168427  202012  9714  ...                             NaN  NaN
# 1168428  202012  9714  ...                             NaN  NaN
# 1168429  202012  9714  ...                             NaN  NaN
# 1168430  202012  9714  ...                             NaN  NaN
# 1168431  202012  9714  ...                             NaN  NaN
#
# [1168432 rows x 65 columns]

# %%
# 소속구 null 갯수 확인
big_df[big_df['소속구'].isnull()]
# Out:
#            사용년월  노선번호                      노선명  표준버스정류장ID  ... ADDR    구   주소  소속구
# 2407     202104   N15            N15번(사당역~우이동)  101000329  ...  NaN  NaN  NaN  NaN
#  39  16시하차총승객수   1028117 non-null  int64
#  40  17시승차총승객수   1028117 non-null  int64
#  41  17시하차총승객수   1028117 non-null  int64
#  42  18시승차총승객수   1028117 non-null  int64
#  43  18시하차총승객수   1028117 non-null  int64
#  44  19시승차총승객수   1028117 non-null  int64
#  45  19시하차총승객수   1028117 non-null  int64
#  46  20시승차총승객수   1028117 non-null  int64
#  47  20시하차총승객수   1028117 non-null  int64
#  48  21시승차총승객수   1028117 non-null  int64
#  49  21시하차총승객수   1028117 non-null  int64
#  50  22시승차총승객수   1028117 non-null  int64
#  51  22시하차총승객수   1028117 non-null  int64
#  52  23시승차총승객수   1028117 non-null  int64
#  53  23시하차총승객수   1028117 non-null  int64
#  54  등록일자        1028117 non-null  int64
#  55  노선ID        413841 non-null   float64
#  56  Unnamed: 0  1028117 non-null  float64
#  57  ARS-ID      1028117 non-null  float64
#  58  Busstop     1028117 non-null  object
#  59  x           1028117 non-null  float64
#  60  y           1028117 non-null  float64
#  61  ADDR        0 non-null        float64
#  62  구           1028117 non-null  object
#  63  주소          1028117 non-null  object
#  64  소속구         1028117 non-null  object
# dtypes: float64(6), int64(50), object(9)
# memory usage: 517.7+ MB

# %%
# 총승차승객수 구
big_df['총승차승객수'] = big_df['00시승차총승객수']+big_df['1시승차총승객수']+big_df['2시승차총승객수']+big_df['3시승차총승객수']+big_df['4시승차총승객수']+big_df['5시승차총승객수']+big_df['6시승차총승객수']+big_df['7시승차총승객수']+big_df['8시승차총승객수']+big_df['9시승차총승객수']+big_df['10시승차총승객수']+big_df['11시승차총승객수']+big_df['12시승차총승객수']+big_df['13시승차총승객수']+big_df['14시승차총승객수']+big_df['15시승차총승객수']+big_df['16시승차총승객수']+big_df['17시승차총승객수']+big_df['18시승차총승객수']+big_df['19시승차총승객수']+big_df['20시승차총승객수']+big_df['21시승차총승객수']+big_df['22시승차총승객수']+big_df['23시승차총승객수']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 총승차승객수 잘 생겼나 확인
big_df.head()
# Out:
#      사용년월 노선번호  ...  소속구 총승차승객수
# 0  202104  N37  ...  종로구     85
# 1  202104  470  ...  종로구   6658
# 2  202104  N37  ...  종로구    139
# 3  202104  741  ...  종로구   5702
# 4  202104  100  ...  종로구   2445
#
# [5 rows x 66 columns]

# %%
big_df.columns
# Out:
# Index(['사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '00시승차총승객수',
#        '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
#        '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
#        '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', '9시승차총승객수',
#        '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
#        '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수',
#        '14시하차총승객수', '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',
#        '17시승차총승객수', '17시하차총승객수', '18시승차총승객수', '18시하차총승객수', '19시승차총승객수',
#        '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', '21시승차총승객수', '21시하차총승객수',
#        '22시승차총승객수', '22시하차총승객수', '23시승차총승객수', '23시하차총승객수', '등록일자', '노선ID',
#        'Unnamed: 0', 'ARS-ID', 'Busstop', 'x', 'y', 'ADDR', '구', '주소', '소속구',
#        '총승차승객수'],
#       dtype='object')

# %%
# 필요한 컬럼만 남김
big_df=big_df.drop( ['노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '00시승차총승객수',
       '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
       '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
       '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', '9시승차총승객수',
       '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
       '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수',
       '14시하차총승객수', '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',
       '17시승차총승객수', '17시하차총승객수', '18시승차총승객수', '18시하차총승객수', '19시승차총승객수',
       '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', '21시승차총승객수', '21시하차총승객수',
       '22시승차총승객수', '22시하차총승객수', '23시승차총승객수', '23시하차총승객수', '등록일자', '노선ID',
       'Unnamed: 0', 'ARS-ID', 'Busstop', 'x', 'y', 'ADDR', '구', '주소'], axis=1)

# %%
# 사용년월 기준으로 정렬
big_df = big_df.sort_values('사용년월')
big_df.head()
# Out:
#           사용년월   소속구  총승차승객수
# 257760  201901  서대문구    1339
# 257306  201901   마포구     116
# 257307  201901   마포구     393
# 257308  201901   마포구     139
# 257309  201901   마포구     566

# %%
# 인간은 실수를 반복한다.
# 아래 코드를 실행시키니 타입 에러 나서 사용일자 타입을 바꿔줌
big_df['사용년월'] = big_df['사용년월'].astype(str)
# big_df['연도'] = big_df['사용일자'].str[0:3]
big_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1028117 entries, 257760 to 78058
# Data columns (total 3 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   사용년월    1028117 non-null  object
#  1   소속구     1028117 non-null  object
#  2   총승차승객수  1028117 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 31.4+ MB

# %%
# 사용일자 형식을 YYYYMM에서 YYYY-MM으로 바
from datetime import datetime

big_df['사용년월'] = [datetime.strptime(x, '%Y%m').strftime('%Y-%m') for x in big_df.사용년월]
big_df.head()
# Out:
#            사용년월   소속구  총승차승객수
# 257760  2019-01  서대문구    1339
# 257306  2019-01   마포구     116
# 257307  2019-01   마포구     393
# 257308  2019-01   마포구     139
# 257309  2019-01   마포구     566

# %% [markdown]
# ## 전체적 전처리는 끝! 이제 기간별나누기

# %%
# 연도,월 컬럼도 만들기 
big_df['연도'] = big_df['사용년월'].str.split('-', expand=True)[0]
big_df['월'] = big_df['사용년월'].str.split('-', expand=True)[1]
big_df.head()
# Out:
#            사용년월   소속구  총승차승객수    연도   월
# 257760  2019-01  서대문구    1339  2019  01
# 257306  2019-01   마포구     116  2019  01
# 257307  2019-01   마포구     393  2019  01
# 257308  2019-01   마포구     139  2019  01
# 257309  2019-01   마포구     566  2019  01

# %%
# 서울시 구 이외의 구 들이 있는지 확인, 확인 해보니 있었음
big_df['소속구'].unique()
# Out:
# array(['서대문구', '마포구', '용산구', '금천구', '동대문구', '동작구', '관악구', '영등포구', '서초구',
#        '강남구', '중구', '종로구', '노원구', '도봉구', '성북구', '강북구', '구로구', '양천구',
#        '성동구', '중랑구', '은평구', '강서구', '광진구', '안양시', '송파구', '성남시', '강동구',
#        '부천시', '하남시', '광명시', '구리시', '양주시'], dtype=object)

# %%
#서울 구만 가져오기
big_df = big_df[big_df['소속구'].isin(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구'])]
big_df
# Out:
#            사용년월   소속구  총승차승객수    연도   월
# 257760  2019-01  서대문구    1339  2019  01
# 257306  2019-01   마포구     116  2019  01
# 257307  2019-01   마포구     393  2019  01
# 257308  2019-01   마포구     139  2019  01
# 257309  2019-01   마포구     566  2019  01
# ...         ...   ...     ...   ...  ..
# 101428  2021-06   금천구     867  2021  06
# 101427  2021-06   금천구    3321  2021  06
# 101426  2021-06   금천구     590  2021  06
# 101432  2021-06   금천구    2384  2021  06
# 78058   2021-06   종로구     100  2021  06
#
# [1025666 rows x 5 columns]

# %% [markdown]
# ## 2019하반기에서 2021까지 버스 값 저장하기

# %%
bus_2019_2021 = big_df.loc[big_df['사용년월'] >='2019-07']
bus_2019_2021.head()
# Out:
#            사용년월  소속구  총승차승객수    연도   월
# 490739  2019-07  성동구    3693  2019  07
# 490738  2019-07  성동구   11993  2019  07
# 490745  2019-07  성동구   13617  2019  07
# 490737  2019-07  성동구    1811  2019  07
# 490744  2019-07  성동구    6921  2019  07

# %%
bus_2019_2021.to_csv('/content/data/버스총데이터.csv', index=False)

# %%
#2019데이터만 가져옴
df_2019 = big_df.loc[big_df['연도'] == '2019']
df_2019.head()
# Out:
#            사용년월   소속구  총승차승객수    연도   월
# 257760  2019-01  서대문구    1339  2019  01
# 257306  2019-01   마포구     116  2019  01
# 257307  2019-01   마포구     393  2019  01
# 257308  2019-01   마포구     139  2019  01
# 257309  2019-01   마포구     566  2019  01

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412832 entries, 257760 to 679544
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   사용년월    412832 non-null  object
#  1   소속구     412832 non-null  object
#  2   총승차승객수  412832 non-null  int64
#  3   연도      412832 non-null  object
#  4   월       412832 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 18.9+ MB

# %%
# 아래 코드 실행시키기 위해 타입변경함 
df_2019['월']=df_2019['월'].astype('int')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 2019하반기만 가져오기
df_2019_fw = df_2019.loc[df_2019['월'] >= 7, :]
df_2019_fw.tail()
# Out:
#            사용년월  소속구  총승차승객수    연도   월
# 672538  2019-12  강서구      17  2019  12
# 672537  2019-12  강서구      78  2019  12
# 672551  2019-12  강서구    1411  2019  12
# 679543  2019-12  강남구    1225  2019  12
# 679544  2019-12  강남구    4921  2019  12

# %%
#2020데이터만 가져옴
df_2020 = big_df.loc[big_df['연도'] == '2020']
df_2020.head()
# Out:
#            사용년월  소속구  총승차승객수    연도   월
# 705508  2020-01  도봉구    1185  2020  01
# 723798  2020-01  성동구      29  2020  01
# 723797  2020-01  성동구    1720  2020  01
# 723796  2020-01  성동구     272  2020  01
# 723795  2020-01  성동구     213  2020  01

# %%
# 아래 코드 실행시키기 위해 타입변경함 
df_2020['월']=df_2020['월'].astype('int')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 2020상반기만 가져오기
df_2020_ss = df_2020.loc[df_2020['월'] <= 6, :]
df_2020_ss.tail()
# Out:
#            사용년월   소속구  총승차승객수    연도  월
# 934036  2020-06  서대문구    1557  2020  6
# 934037  2020-06  서대문구    1024  2020  6
# 934038  2020-06  서대문구     530  2020  6
# 934039  2020-06  서대문구     186  2020  6
# 934033  2020-06   은평구     237  2020  6

# %%
# 2020상반기만 가져오기
df_2020_fw = df_2020.loc[df_2020['월'] >= 7, :]
df_2020_fw.head()
# Out:
#            사용년월  소속구  총승차승객수    연도  월
# 958335  2020-07  성북구       8  2020  7
# 958336  2020-07  성북구      12  2020  7
# 958337  2020-07  성북구     725  2020  7
# 958338  2020-07  성북구      70  2020  7
# 958339  2020-07  성북구      17  2020  7

# %%
#2020데이터만 가져옴
df_2021 = big_df.loc[big_df['연도'] == '2021']
df_2021.head()
# Out:
#           사용년월  소속구  총승차승객수    연도   월
# 77547  2021-01  강동구    4282  2021  01
# 50922  2021-01  강서구    2659  2021  01
# 50921  2021-01  강서구    1689  2021  01
# 50920  2021-01  강서구    2841  2021  01
# 50919  2021-01  강서구    3995  2021  01

# %%
# df_2021.to_csv('/content/data/지하철2021.csv', index=False)

# %% [markdown]
# ## 막대그래프로 흐름 파악하기

# %%
df_2019_fw_sum=df_2019_fw[['소속구','총승차승객수']].groupby('소속구').sum()
df_2019_fw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206941 entries, 490739 to 679544
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   사용년월    206941 non-null  object
#  1   소속구     206941 non-null  object
#  2   총승차승객수  206941 non-null  int64
#  3   연도      206941 non-null  object
#  4   월       206941 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 9.5+ MB

# %%
df_2020_ss_sum=df_2020_ss[['소속구','총승차승객수']].groupby('소속구').sum()
df_2020_ss_sum=df_2020_ss_sum.reset_index()
df_2020_ss_sum
# Out:
#      소속구    총승차승객수
# 0    강남구  44246585
# 1    강동구  15211029
# 2    강북구  27082462
# 3    강서구  25377454
# 4    관악구  38018169
# 5    광진구  14364896
# 6    구로구  26481298
# 7    금천구  20264078
# 8    노원구  21483551
# 9    도봉구  17062736
# 10  동대문구  26137298
# 11   동작구  28243118
# 12   마포구  27810174
# 13  서대문구  30324822
# 14   서초구  36601117
# 15   성동구  16267010
# 16   성북구  31572702
# 17   송파구  26673896
# 18   양천구  22295650
# 19  영등포구  30789959
# 20   용산구  20705014
# 21   은평구  26693036
# 22   종로구  29651976
# 23    중구  19760406
# 24   중랑구  20027580

# %%
df_2020_fw_sum=df_2020_fw[['소속구','총승차승객수']].groupby('소속구').sum()
df_2020_fw_sum=df_2020_fw_sum.reset_index()
df_2020_fw_sum
# Out:
#      소속구    총승차승객수
# 0    강남구  46420884
# 1    강동구  16560858
# 2    강북구  28394476
# 3    강서구  27043435
# 4    관악구  40530237
# 5    광진구  14884632
# 6    구로구  28480931
# 7    금천구  21367731
# 8    노원구  23199970
# 9    도봉구  18199148
# 10  동대문구  27621291
# 11   동작구  29647237
# 12   마포구  27811468
# 13  서대문구  30797854
# 14   서초구  36845015
# 15   성동구  16934302
# 16   성북구  32195696
# 17   송파구  29140462
# 18   양천구  23713438
# 19  영등포구  31502222
# 20   용산구  21405276
# 21   은평구  28763086
# 22   종로구  29700098
# 23    중구  19655433
# 24   중랑구  20901895

# %%
df_2021_sum=df_2021[['소속구','총승차승객수']].groupby('소속구').sum()
df_2021_sum=df_2021_sum.reset_index()

# %%
df_2019_fw_sum=df_2019_fw[['소속구','총승차승객수']].groupby('소속구').sum()
df_2019_fw_sum=df_2019_fw_sum.reset_index()

# %% [markdown]
# ## 5구로 나누는 함수 적용하기

# %%
def set_five(row,value):
    return value[row]

five_gu = {'강남구':'강남구','강동구':'강남구','송파구':'강남구','서초구':'강남구',
           '동작구':'강서구','관악구':'강서구','금천구':'강서구','영등포구':'강서구','양천구':'강서구','구로구':'강서구','강서구':'강서구',
           '중랑구':'중랑구','광진구':'중랑구','동대문구':'중랑구','성동구':'중랑구',
           '은평구':'중구','종로구':'중구','서대문구':'중구','마포구':'중구','용산구':'중구','중구':'중구',
           '도봉구':'강북구','강북구':'강북구','성북구':'강북구','노원구':'강북구'
           }

# %%
# 분류 오구 컬럼 제작
df_2019_fw['오구']=df_2019_fw['소속구'].apply(set_five, args=(five_gu, ))

df_2019_fw.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            사용년월  소속구  총승차승객수    연도  월   오구
# 490739  2019-07  성동구    3693  2019  7  중랑구
# 490738  2019-07  성동구   11993  2019  7  중랑구
# 490745  2019-07  성동구   13617  2019  7  중랑구
# 490737  2019-07  성동구    1811  2019  7  중랑구
# 490744  2019-07  성동구    6921  2019  7  중랑구

# %%
df_2020_ss['오구']=df_2020_ss['소속구'].apply(set_five, args=(five_gu, ))

df_2020_ss.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            사용년월  소속구  총승차승객수    연도  월   오구
# 705508  2020-01  도봉구    1185  2020  1  강북구
# 723798  2020-01  성동구      29  2020  1  중랑구
# 723797  2020-01  성동구    1720  2020  1  중랑구
# 723796  2020-01  성동구     272  2020  1  중랑구
# 723795  2020-01  성동구     213  2020  1  중랑구

# %%
df_2020_fw['오구']=df_2020_fw['소속구'].apply(set_five, args=(five_gu, ))

df_2020_fw.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            사용년월  소속구  총승차승객수    연도  월   오구
# 958335  2020-07  성북구       8  2020  7  강북구
# 958336  2020-07  성북구      12  2020  7  강북구
# 958337  2020-07  성북구     725  2020  7  강북구
# 958338  2020-07  성북구      70  2020  7  강북구
# 958339  2020-07  성북구      17  2020  7  강북구

# %%
df_2021['오구']=df_2021['소속구'].apply(set_five, args=(five_gu, ))

df_2021.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           사용년월  소속구  총승차승객수    연도   월   오구
# 77547  2021-01  강동구    4282  2021  01  강남구
# 50922  2021-01  강서구    2659  2021  01  강서구
# 50921  2021-01  강서구    1689  2021  01  강서구
# 50920  2021-01  강서구    2841  2021  01  강서구
# 50919  2021-01  강서구    3995  2021  01  강서구

# %% [markdown]
# ## 전체 기간 막대그래프 그려보기

# %%
#2019년승차자 흐름 보기
# sns.set_style('whitegrid')
sns.set(font="NanumBarunGothic", 
        # rc={"axes.unicode_minus":False},
        style='whitegrid')
plt.figure(figsize=(24,8))
sns.barplot(
    x='사용년월',
    y='총승차승객수',
    hue='소속구',
    data = df_2019_fw,
    ci=None,
    palette = 'cool_r'

)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
#그래프 저장
plt.savefig('/content/data/2019하반기승차자_버스.png',dpi=100)
plt.show()

# %%
# 오구 나눈 2019보기
sns.set(font="NanumBarunGothic", 
        # rc={"axes.unicode_minus":False},
        style='whitegrid')
plt.figure(figsize=(24,8))
sns.barplot(
    x='사용년월',
    y='총승차승객수',
    hue='오구',
    data=df_2019_fw.sort_values(['사용년월']),
    ci=None,
    palette = 'cool_r'

)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
#그래프 저장
plt.savefig('/content/data/2019_하반기_오구_승차자_버스.png',dpi=100)
plt.show()

# %%
#2020년상반기승차자 흐름 보기
# sns.set_style('whitegrid')
sns.set(font="NanumBarunGothic", 
        # rc={"axes.unicode_minus":False},
        style='whitegrid')
plt.figure(figsize=(24,8))
sns.barplot(
    x='사용년월',
    y='총승차승객수',
    hue='소속구',
    # palette='coolwarm_r',
    # palette='gist_earth_r',
    data=df_2020_ss.sort_values(['사용년월']),
    ci=None,
    palette = 'cool_r'
    
)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
#그래프 저장
plt.savefig('/content/data/2020상반기승차자_버스.png',dpi=100)
plt.show()

# %%
#오구별 2020년상반기승차자 흐름 보기
# sns.set_style('whitegrid')
sns.set(font="NanumBarunGothic", 
        # rc={"axes.unicode_minus":False},
        style='whitegrid')
plt.figure(figsize=(24,8))
sns.barplot(
    x='사용년월',
    y='총승차승객수',
    hue='오구',
    # palette='coolwarm_r',
    # palette='gist_earth_r',
    data=df_2020_ss,
    palette = 'cool_r',
    ci=None
)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
#그래프 저장
plt.savefig('/content/data/2020_상반기_오구승차자_버스.png',dpi=100)
plt.show()

# %%
# sns.set_style('whitegrid')
sns.set(font="NanumBarunGothic", 
        # rc={"axes.unicode_minus":False},
        style='whitegrid')
plt.figure(figsize=(24,8))
sns.barplot(
    x='사용년월',
    y='총승차승객수',
    hue='소속구',
    # palette='gnuplot2',
    data=df_2020_fw.sort_values(['사용년월']),
    ci=None,
    palette = 'cool_r'
)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
#그래프 저장
plt.savefig('/content/data/2020하반기승차자_버스.png',dpi=100)
plt.show()

# %%
#오구별
# sns.set_style('whitegrid')
sns.set(font="NanumBarunGothic", 
        # rc={"axes.unicode_minus":False},
        style='whitegrid',
        # plt.ylim(bottom=3000)
        )
plt.figure(figsize=(24,8))
sns.barplot(
    x='사용년월',
    y='총승차승객수',
    hue='오구',
    # palette='gnuplot2',
    data=df_2020_fw.sort_values(['사용년월']),
    ci=None,
    palette = 'cool_r'
)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
#그래프 저장
plt.savefig('/content/data/2020_하반기_오구승차자_버스.png',dpi=100)
plt.show()

# %%
# sns.set_style('whitegrid')
sns.set(font="NanumBarunGothic", 
        # rc={"axes.unicode_minus":False},
        style='whitegrid',
        # plt.ylim(bottom=3000)
        )
plt.figure(figsize=(24,8))
sns.barplot(
    x='사용년월',
    y='총승차승객수',
    hue='소속구',
    # palette='bone',
    data=df_2021.sort_values(['사용년월']),
    ci=None,
    palette = 'cool_r'

)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
#그래프 저장
plt.savefig('/content/data/2021승차자_버스.png',dpi=100)
plt.show()

# %%
sns.set(font="NanumBarunGothic", 
        # rc={"axes.unicode_minus":False},
        style='whitegrid')
plt.figure(figsize=(24,8))
sns.barplot(
    x='사용년월',
    y='총승차승객수',
    hue='오구',
    # palette='bone',
    data=df_2021.sort_values(['사용년월']),
    ci=None,
    palette = 'cool_r'
)
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))
#그래프 저장
plt.savefig('/content/data/2021_오구승차자_버스.png',dpi=100)
plt.show()

# %% [markdown]
# ## 버스 지도 시각화

# %% [markdown]
# #### 위에 sum들이 있어서 바로 가능

# %%
import folium
import pandas as pd
import re

# %%
geo_json='https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

# %%
df_2019_fw_sum.columns = ['name','values']
df_2019_sum = df_2019_fw_sum.sort_values(by='name')

# %%
# 컬럼 명을 바꿔준다.
df_2020_ss_sum.columns = ['name','values']
# df_2020_ss_sum = df_2020_ss_sum.sort_values(by='name')

# %%
df_2020_fw_sum.columns = ['name','values']
# df_2020_fw_sum = df_2020_fw_sum.sort_values(by='name')

# %%
df_2021_sum.columns = ['name','values']
# df_2021_sum = df_2021_sum.sort_values(by='name')

# %%
#  줌을 10으로 설정
m = folium.Map(
    location=[37.566345,126.977893],
    tiles='cartodbpositron',
    zoom_start=10
)

#색을 조정할 수 있음

folium.Choropleth(
    geo_data=geo_json,
    name='choropleth',
    data=df_2019_sum,
    columns=['name','values'],
    key_on='feature.properties.name',
    # fill_color='YlGn',
    fill_color='BuPu',
    # fill_color='cool_r',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='2019_구별_버스탑승객수'
).add_to(m)

#저장
m.save('2019_구별_버스탑승객수.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_b630d91c44674de78eea4b8fc383e8b6%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b630d91c44674de78eea4b8fc383e8b6%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_b630d91c44674de78eea4b8fc383e8b6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_b630d91c44674de78eea4b8fc383e8b6%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.566345%2C%20126.977893%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_ccf13f0d0c0041bdb88756ab910220da%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/light_al ...

# %%
m = folium.Map(
    location=[37.566345,126.977893],
    tiles='cartodbpositron',
    zoom_start=10
)

#색을 조정할 수 있음

folium.Choropleth(
    geo_data=geo_json,
    name='choropleth',
    data=df_2020_ss_sum,
    columns=['name','values'],
    key_on='feature.properties.name',
    # fill_color='YlGn',
    # fill_color='BuPu',
    # fill_color='Set1_r',
    fill_color='BuPu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='2020상반기_구별_버스탑승객수'
).add_to(m)

#저장
m.save('2020상반기_구별_버스탑승객수.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_8986495ad7154f72ade25feda9a9d112%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8986495ad7154f72ade25feda9a9d112%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_8986495ad7154f72ade25feda9a9d112%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_8986495ad7154f72ade25feda9a9d112%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.566345%2C%20126.977893%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_55da07187141452fa78819459a0b8850%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/light_al ...

# %%
m = folium.Map(
    location=[37.566345,126.977893],
    tiles='cartodbpositron',
    zoom_start=10
)

#색을 조정할 수 있음

folium.Choropleth(
    geo_data=geo_json,
    name='choropleth',
    data=df_2020_fw_sum,
    columns=['name','values'],
    key_on='feature.properties.name',
    # fill_color='YlGn',
    # fill_color='BuPu',
    # fill_color='Oranges_r',
    fill_color='BuPu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='2020하반기_구별_버스탑승객수'
).add_to(m)

#저장
m.save('2020하반기_구별_버스탑승객수.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_588bbc7242ea46169e5972d8db17a73f%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_588bbc7242ea46169e5972d8db17a73f%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_588bbc7242ea46169e5972d8db17a73f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_588bbc7242ea46169e5972d8db17a73f%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.566345%2C%20126.977893%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_7669271d37b146ef85d84cdb7a2f087d%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/light_al ...

# %%
m = folium.Map(
    location=[37.566345,126.977893],
    tiles='cartodbpositron',
    zoom_start=10
)

#색을 조정할 수 있음

folium.Choropleth(
    geo_data=geo_json,
    name='choropleth',
    data=df_2021_sum,
    columns=['name','values'],
    key_on='feature.properties.name',
    # fill_color='YlGn',
    # fill_color='BuPu',
    fill_color='BuPu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='2021_구별_버스탑승객수'
).add_to(m)

#저장
m.save('2021_구별_버스탑승객수.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_819c8ab97ae24c7a897ae2107d1aa882%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_819c8ab97ae24c7a897ae2107d1aa882%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_819c8ab97ae24c7a897ae2107d1aa882%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_819c8ab97ae24c7a897ae2107d1aa882%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.566345%2C%20126.977893%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_6cf64ab17e5f4b8daf3ad3c939b26026%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/light_al ...
