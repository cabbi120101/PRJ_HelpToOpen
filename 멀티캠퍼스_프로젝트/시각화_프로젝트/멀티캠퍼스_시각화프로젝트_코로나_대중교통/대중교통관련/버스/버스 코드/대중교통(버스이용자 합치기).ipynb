# %%
import pandas as pd
import glob
import os
import csv
import glob
import os
import sys

# %%
#csv 파일들 디렉토리 위치
input_file = r'/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터'

output_file = r'/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스/bus_all_all.csv'

allfile_list=glob.glob(os.path.join(input_file, 'BUS_*.csv'))
print(allfile_list)
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/BUS_2021년_버스노선별_정류장별_시간대별_승하차_인원_정보(04월).csv', '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/BUS_2021년_버스노선별_정류장별_시간대별_승하차_인원_정보(01월).csv', '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/BUS_2021년_버스노선별_정류장별_시간대별_승하차_인원_정보(06월).csv', '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/BUS_2021년_버스노선별_정류장별_시간대별_승하차_인원_정보(02월).csv', '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/BUS_2021년_버스노선별_정류장별_시간대별_승하차_인원_정보(03월).csv', '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/BUS_2021년_버스노선별_정류장별_시간대별_승하차_인원_정보(05월).csv', '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/BUS_2019년 버스노선별 정류장별 시간대별 승하차 인원 정보1.csv', '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/BUS_2020년_버스노선별_정류장별_시간대별_승하차_인원_정보.csv']

# %%
data_file = '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/2021년_버스노선별_정류장별_시간대별_승하차_인원_정보(03월).csv'
df = pd.read_csv(data_file, encoding='cp949')
df.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '00시승차총승객수',
#        '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
#        '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
#        '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', '9시승차총승객수',
#        '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
#        '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수',
#        '14시하차총승객수', '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',
#        '17시승차총승객수', '17시하차총승객수', '18시승차총승객수', '18시하차총승객수', '19시승차총승객수',
#        '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', '21시승차총승객수', '21시하차총승객수',
# ...

# %%
data_file = '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스데이터/2020년_버스노선별_정류장별_시간대별_승하차_인원_정보.csv'
df = pd.read_csv(data_file, encoding='cp949')
df.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '00시승차총승객수',
#        '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
#        '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
#        '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', '9시승차총승객수',
#        '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
#        '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수',
#        '14시하차총승객수', '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',
#        '17시승차총승객수', '17시하차총승객수', '18시승차총승객수', '18시하차총승객수', '19시승차총승객수',
#        '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', '21시승차총승객수', '21시하차총승객수',
# ...

# %%
allData = []
for thisfile in allfile_list:
    
    try:
        df = pd.read_csv(thisfile, encoding='cp949')
        # this_encoding = "utf-8"
    except:
        try:
            df = pd.red_csv(thisfile, encoding='uft-8')
            # this_encoding = "cp949"
        except:
            try:
                df = pd.red_csv(thisfile, encoding='euc-kr')
                # this_encoding = "euc-kr"
            except:
                try:
                    df = pd.red_csv(thisfile, encoding='utf-16')
                    # this_encoding = "utf-16"
                except:
                    try:
                        df = pd.red_csv(thisfile, encoding='latin-1').reset_index(drop=True)
                        # this_encoding = "latin-1"
                    except:
                        print(thisfile,'예외')
                        continue # 다음 루프로 건너 뜀
    
    # # 하나씩 밀린 경우를 찾음
    # if df["사용년월"].isna().sum() == len(df):

    #     # 모든 등록일자가 nan임
    #     df = df.reset_index()
    #     df.columns = '사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '00시승차총승객수',
    #    '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
    #    '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
    #    '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', '9시승차총승객수',
    #    '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
    #    '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수',
    #    '14시하차총승객수', '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',
    #    '17시승차총승객수', '17시하차총승객수', '18시승차총승객수', '18시하차총승객수', '19시승차총승객수',
    #    '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', '21시승차총승객수', '21시하차총승객수',
    #    '22시승차총승객수', '22시하차총승객수', '23시승차총승객수', '23시하차총승객수', '등록일자','낸'
    #     df = df.drop(["낸"], axis=1)
    
    allData.append(df)
    display(df.head())
    
dataCombine = pd.concat(allData, axis=0, ignore_index=True)

dataCombine.to_csv(output_file, index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      사용년월 노선번호                    노선명  ...  23시승차총승객수 23시하차총승객수      등록일자
# 0  202104  N37  N37번(송파공영차고지~진관공영차고지)  ...          0         0  20210503
# 1  202104  470       470번(상암차고지~안골마을)  ...        131        69  20210503
# 2  202104  N37  N37번(진관공영차고지~송파공영차고지)  ...          0         0  20210503
# 3  202104  741      741번(진관차고지~헌인릉입구)  ...        133        60  20210503
# 4  202104  100         100번(하계동~용산구청)  ...         14         9  20210503
#
# [5 rows x 55 columns]
#      사용년월 노선번호             노선명  ...  23시승차총승객수 23시하차총승객수      등록일자
# 0  202101  100  100번(하계동~용산구청)  ...         18         4  20210203
# 1  202101  100  100번(하계동~용산구청)  ...         11        10  20210203
# ...

# %%
data_file = '/content/drive/MyDrive/Colab Notebooks/코로나관련/대중교통관련/버스/bus_all_all.csv'
df = pd.read_csv(data_file)
df.head()
df.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            사용년월  노선번호              노선명  ... 23시하차총승객수      등록일자 노선ID
# 1168427  202012  9714  9714번(교하운정~서울역)  ...        53  20210103  NaN
# 1168428  202012  9714  9714번(교하운정~서울역)  ...        16  20210103  NaN
# 1168429  202012  9714  9714번(교하운정~서울역)  ...        46  20210103  NaN
# 1168430  202012  9714  9714번(교하운정~서울역)  ...         0  20210103  NaN
# 1168431  202012  9714  9714번(교하운정~서울역)  ...         0  20210103  NaN
#
# [5 rows x 56 columns]
